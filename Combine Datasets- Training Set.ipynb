# %% [markdown]
# ## Notes:
# This training set is made up of data in the New Data folder. All of the data is for the year 2015.

# %%
import pandas as pd
import pathlib

# %%
new_data_path = pathlib.Path.cwd()/'New Data'

# %% [markdown]
# ## adolescent birth rate - DONE

# %%
ad_br_2015 = pd.read_csv(new_data_path/'ad_br_2015.csv')
ad_br_2015
# Out:
#                                               Location  Period  \
# 0                                              Albania    2015
# 1                                              Algeria    2015
# 2                                              Andorra    2015
# 3                                  Antigua and Barbuda    2015
# 4                                            Argentina    2015
# ..                                                 ...     ...
# 101                                             Turkey    2015
# 102                                             Uganda    2015
# 103  United Kingdom of Great Britain and Northern I...    2015
# 104                           United States of America    2015
# 105                                            Uruguay    2015
#
#                                              Indicator  First Tooltip
# 0    Adolescent birth rate (per 1000 women aged 15-...           20.2
# ...

# %%
ad_br_2015.columns = ['Location', 'Period', 'Indicator', 'AdBirthRate']

# %%
ad_br_2015
# Out:
#                                               Location  Period  \
# 0                                              Albania    2015
# 1                                              Algeria    2015
# 2                                              Andorra    2015
# 3                                  Antigua and Barbuda    2015
# 4                                            Argentina    2015
# ..                                                 ...     ...
# 101                                             Turkey    2015
# 102                                             Uganda    2015
# 103  United Kingdom of Great Britain and Northern I...    2015
# 104                           United States of America    2015
# 105                                            Uruguay    2015
#
#                                              Indicator  AdBirthRate
# 0    Adolescent birth rate (per 1000 women aged 15-...         20.2
# 1    Adolescent birth rate (per 1000 women aged 15-...          9.7
# ...

# %%
ad_br_2015 = ad_br_2015.drop(['Period', 'Indicator'], 1)
ad_br_2015
# Out:
#                                               Location  AdBirthRate
# 0                                              Albania         20.2
# 1                                              Algeria          9.7
# 2                                              Andorra          3.1
# 3                                  Antigua and Barbuda         37.7
# 4                                            Argentina         65.1
# ..                                                 ...          ...
# 101                                             Turkey         24.9
# 102                                             Uganda        131.5
# 103  United Kingdom of Great Britain and Northern I...         14.4
# 104                           United States of America         22.3
# 105                                            Uruguay         55.6
#
# [106 rows x 2 columns]

# %% [markdown]
# ## alcohol - DONE

# %%
alcohol_2015 = pd.read_csv(new_data_path/'alchohol_bs_2015.csv')
alcohol_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                               Andorra    2015
# 4                                Angola    2015
# ..                                  ...     ...
# 183  Venezuela (Bolivarian Republic of)    2015
# 184                            Viet Nam    2015
# 185                               Yemen    2015
# 186                              Zambia    2015
# 187                            Zimbabwe    2015
#
#                                              Indicator        Dim1  \
# 0    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# 1    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# 2    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# 3    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# ...

# %%
alcohol_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Alcohol']

# %%
alcohol_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                               Andorra    2015
# 4                                Angola    2015
# ..                                  ...     ...
# 183  Venezuela (Bolivarian Republic of)    2015
# 184                            Viet Nam    2015
# 185                               Yemen    2015
# 186                              Zambia    2015
# 187                            Zimbabwe    2015
#
#                                              Indicator        Dim1  Alcohol
# 0    Total (recorded+unrecorded) alcohol per capita...  Both sexes    0.210
# 1    Total (recorded+unrecorded) alcohol per capita...  Both sexes    6.740
# 2    Total (recorded+unrecorded) alcohol per capita...  Both sexes    0.930
# 3    Total (recorded+unrecorded) alcohol per capita...  Both sexes   11.010
# ...

# %%
alcohol_2015 = alcohol_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
alcohol_2015
# Out:
#                                Location  Alcohol
# 0                           Afghanistan    0.210
# 1                               Albania    6.740
# 2                               Algeria    0.930
# 3                               Andorra   11.010
# 4                                Angola    7.960
# ..                                  ...      ...
# 183  Venezuela (Bolivarian Republic of)    6.820
# 184                            Viet Nam    7.860
# 185                               Yemen    0.055
# 186                              Zambia    6.890
# 187                            Zimbabwe    4.920
#
# [188 rows x 2 columns]

# %% [markdown]
# ## basic sanitization - DONE

# %%
sani_2015 = pd.read_csv(new_data_path/'basic_sani_tot_2015.csv')
sani_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 188  Venezuela (Bolivarian Republic of)
# 189                            Viet Nam
# 190                               Yemen
# 191                              Zambia
# 192                            Zimbabwe
#
#                                              Indicator  Period   Dim1  \
# 0    Population using at least basic sanitation ser...    2015  Total
# 1    Population using at least basic sanitation ser...    2015  Total
# 2    Population using at least basic sanitation ser...    2015  Total
# 3    Population using at least basic sanitation ser...    2015  Total
# 4    Population using at least basic sanitation ser...    2015  Total
# ...

# %%
sani_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'BasicSanitization']

# %%
sani_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 188  Venezuela (Bolivarian Republic of)
# 189                            Viet Nam
# 190                               Yemen
# 191                              Zambia
# 192                            Zimbabwe
#
#                                                 Period  Indicator   Dim1  \
# 0    Population using at least basic sanitation ser...       2015  Total
# 1    Population using at least basic sanitation ser...       2015  Total
# 2    Population using at least basic sanitation ser...       2015  Total
# 3    Population using at least basic sanitation ser...       2015  Total
# 4    Population using at least basic sanitation ser...       2015  Total
# ...

# %%
sani_2015 = sani_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
sani_2015
# Out:
#                                Location  BasicSanitization
# 0                           Afghanistan              40.71
# 1                               Albania              97.69
# 2                               Algeria              87.50
# 3                               Andorra             100.00
# 4                                Angola              47.37
# ..                                  ...                ...
# 188  Venezuela (Bolivarian Republic of)              93.94
# 189                            Viet Nam              80.08
# 190                               Yemen              58.50
# 191                              Zambia              25.98
# 192                            Zimbabwe              37.57
#
# [193 rows x 2 columns]

# %% [markdown]
# ## cancer - DONE

# %%
cancer_2015 = pd.read_csv(new_data_path/'cancer_bs_2015.csv')
cancer_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                                              Indicator        Dim1  \
# 0    Probability (%) of dying between age 30 and ex...  Both sexes
# 1    Probability (%) of dying between age 30 and ex...  Both sexes
# 2    Probability (%) of dying between age 30 and ex...  Both sexes
# 3    Probability (%) of dying between age 30 and ex...  Both sexes
# ...

# %%
cancer_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'CancerEtc']

# %%
cancer_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                                              Indicator        Dim1  CancerEtc
# 0    Probability (%) of dying between age 30 and ex...  Both sexes       29.8
# 1    Probability (%) of dying between age 30 and ex...  Both sexes       17.4
# 2    Probability (%) of dying between age 30 and ex...  Both sexes       14.4
# ...

# %%
cancer_2015 = cancer_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
cancer_2015
# Out:
#                                Location  CancerEtc
# 0                           Afghanistan       29.8
# 1                               Albania       17.4
# 2                               Algeria       14.4
# 3                                Angola       16.9
# 4                   Antigua and Barbuda       22.6
# ..                                  ...        ...
# 178  Venezuela (Bolivarian Republic of)       18.2
# 179                            Viet Nam       17.3
# 180                               Yemen       30.7
# 181                              Zambia       18.0
# 182                            Zimbabwe       19.4
#
# [183 rows x 2 columns]

# %% [markdown]
# ## doctors - DONE

# %%
doc_2015 = pd.read_csv(new_data_path/'doc_2015.csv')
doc_2015
# Out:
#                                               Location  Period  \
# 0                                          Afghanistan    2015
# 1                                              Andorra    2015
# 2                                              Armenia    2015
# 3                                            Australia    2015
# 4                                              Austria    2015
# ..                                                 ...     ...
# 100                               United Arab Emirates    2015
# 101  United Kingdom of Great Britain and Northern I...    2015
# 102                           United States of America    2015
# 103                                           Viet Nam    2015
# 104                                           Zimbabwe    2015
#
#                         Indicator  First Tooltip
# 0    Medical doctors (per 10,000)           2.85
# 1    Medical doctors (per 10,000)          33.33
# 2    Medical doctors (per 10,000)          29.14
# ...

# %%
doc_2015.columns = ['Location', 'Period', 'Indicator', 'MedDocs']

# %%
doc_2015
# Out:
#                                               Location  Period  \
# 0                                          Afghanistan    2015
# 1                                              Andorra    2015
# 2                                              Armenia    2015
# 3                                            Australia    2015
# 4                                              Austria    2015
# ..                                                 ...     ...
# 100                               United Arab Emirates    2015
# 101  United Kingdom of Great Britain and Northern I...    2015
# 102                           United States of America    2015
# 103                                           Viet Nam    2015
# 104                                           Zimbabwe    2015
#
#                         Indicator  MedDocs
# 0    Medical doctors (per 10,000)     2.85
# 1    Medical doctors (per 10,000)    33.33
# 2    Medical doctors (per 10,000)    29.14
# ...

# %%
doc_2015 = doc_2015.drop(['Period', 'Indicator'], 1)
doc_2015
# Out:
#                                               Location  MedDocs
# 0                                          Afghanistan     2.85
# 1                                              Andorra    33.33
# 2                                              Armenia    29.14
# 3                                            Australia    34.89
# 4                                              Austria    51.04
# ..                                                 ...      ...
# 100                               United Arab Emirates    22.11
# 101  United Kingdom of Great Britain and Northern I...    27.47
# 102                           United States of America    25.78
# 103                                           Viet Nam     7.96
# 104                                           Zimbabwe     1.82
#
# [105 rows x 2 columns]

# %% [markdown]
# ## healthy life expectancy - DONE

# %%
hale_2015 = pd.read_csv(new_data_path/'HALE_bs_2015.csv')
hale_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                                            Indicator        Dim1  \
# 0    Healthy life expectancy (HALE) at birth (years)  Both sexes
# 1    Healthy life expectancy (HALE) at birth (years)  Both sexes
# 2    Healthy life expectancy (HALE) at birth (years)  Both sexes
# 3    Healthy life expectancy (HALE) at birth (years)  Both sexes
# ...

# %%
hale_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'HALE']

# %%
hale_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                                            Indicator        Dim1   HALE
# 0    Healthy life expectancy (HALE) at birth (years)  Both sexes  52.60
# 1    Healthy life expectancy (HALE) at birth (years)  Both sexes  69.03
# 2    Healthy life expectancy (HALE) at birth (years)  Both sexes  65.99
# 3    Healthy life expectancy (HALE) at birth (years)  Both sexes  53.66
# ...

# %%
hale_2015 = hale_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
hale_2015
# Out:
#                                Location   HALE
# 0                           Afghanistan  52.60
# 1                               Albania  69.03
# 2                               Algeria  65.99
# 3                                Angola  53.66
# 4                   Antigua and Barbuda  66.81
# ..                                  ...    ...
# 178  Venezuela (Bolivarian Republic of)  65.10
# 179                            Viet Nam  64.89
# 180                               Yemen  58.38
# 181                              Zambia  52.71
# 182                            Zimbabwe  51.17
#
# [183 rows x 2 columns]

# %% [markdown]
# ## HIV - DONE

# %%
hiv_2015 = pd.read_csv(new_data_path/'hiv_bs_2015.csv')
hiv_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                             Argentina    2015
# ..                                  ...     ...
# 165  Venezuela (Bolivarian Republic of)    2015
# 166                            Viet Nam    2015
# 167                               Yemen    2015
# 168                              Zambia    2015
# 169                            Zimbabwe    2015
#
#                                              Indicator        Dim1  \
# 0    New HIV infections (per 1000 uninfected popula...  Both sexes
# 1    New HIV infections (per 1000 uninfected popula...  Both sexes
# 2    New HIV infections (per 1000 uninfected popula...  Both sexes
# 3    New HIV infections (per 1000 uninfected popula...  Both sexes
# ...

# %%
hiv_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'HIV']

# %%
hiv_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                             Argentina    2015
# ..                                  ...     ...
# 165  Venezuela (Bolivarian Republic of)    2015
# 166                            Viet Nam    2015
# 167                               Yemen    2015
# 168                              Zambia    2015
# 169                            Zimbabwe    2015
#
#                                              Indicator        Dim1  \
# 0    New HIV infections (per 1000 uninfected popula...  Both sexes
# 1    New HIV infections (per 1000 uninfected popula...  Both sexes
# 2    New HIV infections (per 1000 uninfected popula...  Both sexes
# 3    New HIV infections (per 1000 uninfected popula...  Both sexes
# ...

# %%
hiv_2015 = hiv_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
hiv_2015
# Out:
#                                Location               HIV
# 0                           Afghanistan  0.03 [0.01-0.11]
# 1                               Albania  0.04 [0.01-0.08]
# 2                               Algeria  0.05 [0.02-0.07]
# 3                                Angola  0.95 [0.73-1.19]
# 4                             Argentina   0.14 [0.11-0.2]
# ..                                  ...               ...
# 165  Venezuela (Bolivarian Republic of)   0.2 [0.14-0.26]
# 166                            Viet Nam  0.11 [0.09-0.12]
# 167                               Yemen  0.04 [0.02-0.07]
# 168                              Zambia  4.11 [3.45-5.04]
# 169                            Zimbabwe   3.91 [2.75-5.4]
#
# [170 rows x 2 columns]

# %% [markdown]
# ## infant mortality - DONE

# %%
inmort_2015 = pd.read_csv(new_data_path/'in_mort_bs_2015.csv')
inmort_2015
# Out:
#                  Location  Period  \
# 0             Afghanistan    2015
# 1                 Albania    2015
# 2                 Algeria    2015
# 3                 Andorra    2015
# 4                  Angola    2015
# ..                    ...     ...
# 167           Switzerland    2015
# 168  Syrian Arab Republic    2015
# 169            Tajikistan    2015
# 170              Thailand    2015
# 171           Timor-Leste    2015
#
#                                              Indicator        Dim1  \
# 0    Infant mortality rate (probability of dying be...  Both sexes
# 1    Infant mortality rate (probability of dying be...  Both sexes
# 2    Infant mortality rate (probability of dying be...  Both sexes
# 3    Infant mortality rate (probability of dying be...  Both sexes
# 4    Infant mortality rate (probability of dying be...  Both sexes
# ..                                                 ...         ...
# 167  Infant mortality rate (probability of dying be...  Both sexes
# ...

# %%
inmort_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'InfantMortality']

# %%
inmort_2015
# Out:
#                  Location  Period  \
# 0             Afghanistan    2015
# 1                 Albania    2015
# 2                 Algeria    2015
# 3                 Andorra    2015
# 4                  Angola    2015
# ..                    ...     ...
# 167           Switzerland    2015
# 168  Syrian Arab Republic    2015
# 169            Tajikistan    2015
# 170              Thailand    2015
# 171           Timor-Leste    2015
#
#                                              Indicator        Dim1  \
# 0    Infant mortality rate (probability of dying be...  Both sexes
# 1    Infant mortality rate (probability of dying be...  Both sexes
# 2    Infant mortality rate (probability of dying be...  Both sexes
# 3    Infant mortality rate (probability of dying be...  Both sexes
# 4    Infant mortality rate (probability of dying be...  Both sexes
# ..                                                 ...         ...
# 167  Infant mortality rate (probability of dying be...  Both sexes
# ...

# %%
inmort_2015 = inmort_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
inmort_2015
# Out:
#                  Location      InfantMortality
# 0             Afghanistan  53.17 [46.81-59.79]
# 1                 Albania     8.51 [8.21-8.84]
# 2                 Algeria   21.61 [21.13-22.1]
# 3                 Andorra    3.34 [1.17-10.03]
# 4                  Angola  57.82 [34.14-91.99]
# ..                    ...                  ...
# 167           Switzerland     3.78 [3.64-3.93]
# 168  Syrian Arab Republic  17.76 [12.16-21.37]
# 169            Tajikistan  32.86 [26.55-40.87]
# 170              Thailand    9.27 [8.14-10.97]
# 171           Timor-Leste  43.24 [30.19-60.58]
#
# [172 rows x 2 columns]

# %% [markdown]
# ## life expectancy at birth - DONE

# %%
leb_2015 = pd.read_csv(new_data_path/'leb_bs_2015.csv')
leb_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                             Indicator        Dim1  First Tooltip
# 0    Life expectancy at birth (years)  Both sexes          61.65
# 1    Life expectancy at birth (years)  Both sexes          77.84
# 2    Life expectancy at birth (years)  Both sexes          76.54
# 3    Life expectancy at birth (years)  Both sexes          61.72
# ...

# %%
leb_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'LifeExpectancy']

# %%
leb_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                             Indicator        Dim1  LifeExpectancy
# 0    Life expectancy at birth (years)  Both sexes           61.65
# 1    Life expectancy at birth (years)  Both sexes           77.84
# 2    Life expectancy at birth (years)  Both sexes           76.54
# 3    Life expectancy at birth (years)  Both sexes           61.72
# ...

# %%
leb_2015 = leb_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
leb_2015
# Out:
#                                Location  LifeExpectancy
# 0                           Afghanistan           61.65
# 1                               Albania           77.84
# 2                               Algeria           76.54
# 3                                Angola           61.72
# 4                   Antigua and Barbuda           76.14
# ..                                  ...             ...
# 178  Venezuela (Bolivarian Republic of)           74.66
# 179                            Viet Nam           73.16
# 180                               Yemen           67.47
# 181                              Zambia           60.50
# 182                            Zimbabwe           58.48
#
# [183 rows x 2 columns]

# %% [markdown]
# ## malaria - DONE

# %%
malaria_2015 = pd.read_csv(new_data_path/'malaria_2015.csv')
malaria_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Algeria
# 2                                Angola
# 3                             Argentina
# 4                               Armenia
# ..                                  ...
# 102  Venezuela (Bolivarian Republic of)
# 103                            Viet Nam
# 104                               Yemen
# 105                              Zambia
# 106                            Zimbabwe
#
#                                             Indicator  Period  First Tooltip
# 0    Malaria incidence (per 1 000 population at risk)    2015          14.91
# 1    Malaria incidence (per 1 000 population at risk)    2015           0.00
# 2    Malaria incidence (per 1 000 population at risk)    2015         200.00
# 3    Malaria incidence (per 1 000 population at risk)    2015           0.00
# 4    Malaria incidence (per 1 000 population at risk)    2015           0.00
# ...

# %%
malaria_2015.columns = ['Location', 'Period', 'Indicator', 'Malaria']

# %%
malaria_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Algeria
# 2                                Angola
# 3                             Argentina
# 4                               Armenia
# ..                                  ...
# 102  Venezuela (Bolivarian Republic of)
# 103                            Viet Nam
# 104                               Yemen
# 105                              Zambia
# 106                            Zimbabwe
#
#                                                Period  Indicator  Malaria
# 0    Malaria incidence (per 1 000 population at risk)       2015    14.91
# 1    Malaria incidence (per 1 000 population at risk)       2015     0.00
# 2    Malaria incidence (per 1 000 population at risk)       2015   200.00
# 3    Malaria incidence (per 1 000 population at risk)       2015     0.00
# 4    Malaria incidence (per 1 000 population at risk)       2015     0.00
# ...

# %%
malaria_2015 = malaria_2015.drop(['Period', 'Indicator'], 1)
malaria_2015
# Out:
#                                Location  Malaria
# 0                           Afghanistan    14.91
# 1                               Algeria     0.00
# 2                                Angola   200.00
# 3                             Argentina     0.00
# 4                               Armenia     0.00
# ..                                  ...      ...
# 102  Venezuela (Bolivarian Republic of)    10.57
# 103                            Viet Nam     0.17
# 104                               Yemen    24.90
# 105                              Zambia   202.50
# 106                            Zimbabwe    97.65
#
# [107 rows x 2 columns]

# %% [markdown]
# ## midwife - DONE

# %%
midwife_2015 = pd.read_csv(new_data_path/'midwife_2015.csv')
midwife_2015
# Out:
#                                               Location  Period  \
# 0                                          Afghanistan    2015
# 1                                              Andorra    2015
# 2                                  Antigua and Barbuda    2015
# 3                                              Armenia    2015
# 4                                            Australia    2015
# ..                                                 ...     ...
# 128                               United Arab Emirates    2015
# 129  United Kingdom of Great Britain and Northern I...    2015
# 130                                           Viet Nam    2015
# 131                                              Yemen    2015
# 132                                           Zimbabwe    2015
#
#                                         Indicator  First Tooltip
# 0    Nursing and midwifery personnel (per 10,000)           1.30
# 1    Nursing and midwifery personnel (per 10,000)          40.13
# ...

# %%
midwife_2015.columns = ['Location', 'Period', 'Indicator', 'MidwifeNursing']

# %%
midwife_2015
# Out:
#                                               Location  Period  \
# 0                                          Afghanistan    2015
# 1                                              Andorra    2015
# 2                                  Antigua and Barbuda    2015
# 3                                              Armenia    2015
# 4                                            Australia    2015
# ..                                                 ...     ...
# 128                               United Arab Emirates    2015
# 129  United Kingdom of Great Britain and Northern I...    2015
# 130                                           Viet Nam    2015
# 131                                              Yemen    2015
# 132                                           Zimbabwe    2015
#
#                                         Indicator  MidwifeNursing
# 0    Nursing and midwifery personnel (per 10,000)            1.30
# 1    Nursing and midwifery personnel (per 10,000)           40.13
# ...

# %%
midwife_2015 = midwife_2015.drop(['Period', 'Indicator'], 1)
midwife_2015
# Out:
#                                               Location  MidwifeNursing
# 0                                          Afghanistan            1.30
# 1                                              Andorra           40.13
# 2                                  Antigua and Barbuda           45.09
# 3                                              Armenia           49.54
# 4                                            Australia          122.00
# ..                                                 ...             ...
# 128                               United Arab Emirates           49.83
# 129  United Kingdom of Great Britain and Northern I...           82.94
# 130                                           Viet Nam           14.23
# 131                                              Yemen            7.24
# 132                                           Zimbabwe           13.83
#
# [133 rows x 2 columns]

# %% [markdown]
# ## maternal mortality rate - DONE

# %%
mmr_2015 = pd.read_csv(new_data_path/'mmr_2015.csv')
mmr_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                                              Indicator   First Tooltip
# 0    Maternal mortality ratio (per 100 000 live bir...  701 [501-1020]
# 1    Maternal mortality ratio (per 100 000 live bir...       15 [8-25]
# 2    Maternal mortality ratio (per 100 000 live bir...    114 [67-199]
# 3    Maternal mortality ratio (per 100 000 live bir...   251 [178-353]
# ...

# %%
mmr_2015.columns = ['Location', 'Period', 'Indicator', 'MaternalMortality']

# %%
mmr_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                                Angola    2015
# 4                   Antigua and Barbuda    2015
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2015
# 179                            Viet Nam    2015
# 180                               Yemen    2015
# 181                              Zambia    2015
# 182                            Zimbabwe    2015
#
#                                              Indicator MaternalMortality
# 0    Maternal mortality ratio (per 100 000 live bir...    701 [501-1020]
# 1    Maternal mortality ratio (per 100 000 live bir...         15 [8-25]
# 2    Maternal mortality ratio (per 100 000 live bir...      114 [67-199]
# 3    Maternal mortality ratio (per 100 000 live bir...     251 [178-353]
# ...

# %%
mmr_2015 = mmr_2015.drop(['Period', 'Indicator'], 1)
mmr_2015
# Out:
#                                Location MaternalMortality
# 0                           Afghanistan    701 [501-1020]
# 1                               Albania         15 [8-25]
# 2                               Algeria      114 [67-199]
# 3                                Angola     251 [178-353]
# 4                   Antigua and Barbuda        43 [25-70]
# ..                                  ...               ...
# 178  Venezuela (Bolivarian Republic of)      115 [92-151]
# 179                            Viet Nam        45 [33-62]
# 180                               Yemen     169 [105-264]
# 181                              Zambia     232 [178-305]
# 182                            Zimbabwe     480 [385-588]
#
# [183 rows x 2 columns]

# %% [markdown]
# ## neonatal mortality rate - DONE

# %%
neo_2015 = pd.read_csv(new_data_path/'neo_mort_bs_2015.csv')
neo_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                               Andorra    2015
# 4                                Angola    2015
# ..                                  ...     ...
# 188  Venezuela (Bolivarian Republic of)    2015
# 189                            Viet Nam    2015
# 190                               Yemen    2015
# 191                              Zambia    2015
# 192                            Zimbabwe    2015
#
#                                           Indicator        Dim1  \
# 0    Neonatal mortality rate (per 1000 live births)  Both sexes
# 1    Neonatal mortality rate (per 1000 live births)  Both sexes
# 2    Neonatal mortality rate (per 1000 live births)  Both sexes
# 3    Neonatal mortality rate (per 1000 live births)  Both sexes
# ...

# %%
neo_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'NeonatalMortality']

# %%
neo_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                               Andorra    2015
# 4                                Angola    2015
# ..                                  ...     ...
# 188  Venezuela (Bolivarian Republic of)    2015
# 189                            Viet Nam    2015
# 190                               Yemen    2015
# 191                              Zambia    2015
# 192                            Zimbabwe    2015
#
#                                           Indicator        Dim1  \
# 0    Neonatal mortality rate (per 1000 live births)  Both sexes
# 1    Neonatal mortality rate (per 1000 live births)  Both sexes
# 2    Neonatal mortality rate (per 1000 live births)  Both sexes
# 3    Neonatal mortality rate (per 1000 live births)  Both sexes
# ...

# %%
neo_2015 = neo_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
neo_2015
# Out:
#                                Location    NeonatalMortality
# 0                           Afghanistan  40.27 [34.34-46.94]
# 1                               Albania     6.03 [5.49-6.54]
# 2                               Algeria   15.05 [14.4-15.68]
# 3                               Andorra     1.71 [0.56-5.27]
# 4                                Angola  30.63 [15.65-53.27]
# ..                                  ...                  ...
# 188  Venezuela (Bolivarian Republic of)  14.45 [13.64-15.31]
# 189                            Viet Nam   11.37 [9.16-13.76]
# 190                               Yemen  26.65 [19.45-36.23]
# 191                              Zambia  24.53 [21.29-28.42]
# 192                            Zimbabwe  27.89 [23.72-32.63]
#
# [193 rows x 2 columns]

# %% [markdown]
# ## NTD - DONE

# %%
ntd_2015 = pd.read_csv(new_data_path/'ntd_2015.csv')
ntd_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                              Indicator  Period  First Tooltip
# 0    Reported number of people requiring interventi...    2015       13765392
# 1    Reported number of people requiring interventi...    2015             16
# 2    Reported number of people requiring interventi...    2015           7561
# 3    Reported number of people requiring interventi...    2015              0
# 4    Reported number of people requiring interventi...    2015       18534219
# ...

# %%
ntd_2015.columns = ['Location', 'Period', 'Indicator', 'NTDs']

# %%
ntd_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                                 Period  Indicator      NTDs
# 0    Reported number of people requiring interventi...       2015  13765392
# 1    Reported number of people requiring interventi...       2015        16
# 2    Reported number of people requiring interventi...       2015      7561
# 3    Reported number of people requiring interventi...       2015         0
# 4    Reported number of people requiring interventi...       2015  18534219
# ...

# %%
ntd_2015 = ntd_2015.drop(['Period', 'Indicator'], 1)
ntd_2015
# Out:
#                                Location      NTDs
# 0                           Afghanistan  13765392
# 1                               Albania        16
# 2                               Algeria      7561
# 3                               Andorra         0
# 4                                Angola  18534219
# ..                                  ...       ...
# 189  Venezuela (Bolivarian Republic of)    280243
# 190                            Viet Nam   4468764
# 191                               Yemen   5840695
# 192                              Zambia  11830416
# 193                            Zimbabwe  10346543
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Poisoning mortality rate - DONE

# %%
poison_2015 = pd.read_csv(new_data_path/'poison_bs_2015.csv')
poison_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                                Angola
# 4                   Antigua and Barbuda
# ..                                  ...
# 178  Venezuela (Bolivarian Republic of)
# 179                            Viet Nam
# 180                               Yemen
# 181                              Zambia
# 182                            Zimbabwe
#
#                                              Indicator  Period        Dim1  \
# 0    Mortality rate attributed to unintentional poi...    2015  Both sexes
# 1    Mortality rate attributed to unintentional poi...    2015  Both sexes
# 2    Mortality rate attributed to unintentional poi...    2015  Both sexes
# 3    Mortality rate attributed to unintentional poi...    2015  Both sexes
# 4    Mortality rate attributed to unintentional poi...    2015  Both sexes
# ...

# %%
poison_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Poisoning']

# %%
poison_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                                Angola
# 4                   Antigua and Barbuda
# ..                                  ...
# 178  Venezuela (Bolivarian Republic of)
# 179                            Viet Nam
# 180                               Yemen
# 181                              Zambia
# 182                            Zimbabwe
#
#                                                 Period  Indicator        Dim1  \
# 0    Mortality rate attributed to unintentional poi...       2015  Both sexes
# 1    Mortality rate attributed to unintentional poi...       2015  Both sexes
# 2    Mortality rate attributed to unintentional poi...       2015  Both sexes
# 3    Mortality rate attributed to unintentional poi...       2015  Both sexes
# 4    Mortality rate attributed to unintentional poi...       2015  Both sexes
# ...

# %%
poison_2015 = poison_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
poison_2015
# Out:
#                                Location  Poisoning
# 0                           Afghanistan       1.22
# 1                               Albania       0.43
# 2                               Algeria       0.80
# 3                                Angola       2.95
# 4                   Antigua and Barbuda       0.38
# ..                                  ...        ...
# 178  Venezuela (Bolivarian Republic of)       0.30
# 179                            Viet Nam       0.93
# 180                               Yemen       3.74
# 181                              Zambia       3.06
# 182                            Zimbabwe       2.37
#
# [183 rows x 2 columns]

# %% [markdown]
# ## tobacco - DONE

# %%
tob_2015 = pd.read_csv(new_data_path/'tob_2015.csv')
tob_2015
# Out:
#        Location                                          Indicator  Period  \
# 0       Albania  Age-standardized prevalence of current tobacco...    2015
# 1       Algeria  Age-standardized prevalence of current tobacco...    2015
# 2       Andorra  Age-standardized prevalence of current tobacco...    2015
# 3     Argentina  Age-standardized prevalence of current tobacco...    2015
# 4       Armenia  Age-standardized prevalence of current tobacco...    2015
# ..          ...                                                ...     ...
# 144  Uzbekistan  Age-standardized prevalence of current tobacco...    2015
# 145     Vanuatu  Age-standardized prevalence of current tobacco...    2015
# 146       Yemen  Age-standardized prevalence of current tobacco...    2015
# 147      Zambia  Age-standardized prevalence of current tobacco...    2015
# 148    Zimbabwe  Age-standardized prevalence of current tobacco...    2015
#
#            Dim1  First Tooltip
# 0    Both sexes           29.9
# ...

# %%
tob_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Tobacco']

# %%
tob_2015
# Out:
#        Location                                             Period  Indicator  \
# 0       Albania  Age-standardized prevalence of current tobacco...       2015
# 1       Algeria  Age-standardized prevalence of current tobacco...       2015
# 2       Andorra  Age-standardized prevalence of current tobacco...       2015
# 3     Argentina  Age-standardized prevalence of current tobacco...       2015
# 4       Armenia  Age-standardized prevalence of current tobacco...       2015
# ..          ...                                                ...        ...
# 144  Uzbekistan  Age-standardized prevalence of current tobacco...       2015
# 145     Vanuatu  Age-standardized prevalence of current tobacco...       2015
# 146       Yemen  Age-standardized prevalence of current tobacco...       2015
# 147      Zambia  Age-standardized prevalence of current tobacco...       2015
# 148    Zimbabwe  Age-standardized prevalence of current tobacco...       2015
#
#            Dim1  Tobacco
# ...

# %%
tob_2015 = tob_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
tob_2015
# Out:
#        Location  Tobacco
# 0       Albania     29.9
# 1       Algeria     19.3
# 2       Andorra     34.2
# 3     Argentina     24.6
# 4       Armenia     27.9
# ..          ...      ...
# 144  Uzbekistan     12.8
# 145     Vanuatu     25.1
# 146       Yemen     22.2
# 147      Zambia     15.4
# 148    Zimbabwe     14.5
#
# [149 rows x 2 columns]

# %% [markdown]
# ## tuberculosis - DONE

# %%
tuber_2015 = pd.read_csv(new_data_path/'tuber_2015.csv')
tuber_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                              Indicator  Period  First Tooltip
# 0    Incidence of tuberculosis (per 100 000 populat...    2015  189 [122-270]
# 1    Incidence of tuberculosis (per 100 000 populat...    2015     17 [14-19]
# 2    Incidence of tuberculosis (per 100 000 populat...    2015     75 [57-94]
# 3    Incidence of tuberculosis (per 100 000 populat...    2015    5.9 [5-6.8]
# 4    Incidence of tuberculosis (per 100 000 populat...    2015  366 [237-523]
# ...

# %%
tuber_2015.columns = ['Location', 'Period', 'Indicator', 'Tuberculosis']

# %%
tuber_2015
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                                 Period  Indicator  \
# 0    Incidence of tuberculosis (per 100 000 populat...       2015
# 1    Incidence of tuberculosis (per 100 000 populat...       2015
# 2    Incidence of tuberculosis (per 100 000 populat...       2015
# 3    Incidence of tuberculosis (per 100 000 populat...       2015
# 4    Incidence of tuberculosis (per 100 000 populat...       2015
# ..                                                 ...        ...
# ...

# %%
tuber_2015 = tuber_2015.drop(['Period', 'Indicator'], 1)
tuber_2015
# Out:
#                                Location   Tuberculosis
# 0                           Afghanistan  189 [122-270]
# 1                               Albania     17 [14-19]
# 2                               Algeria     75 [57-94]
# 3                               Andorra    5.9 [5-6.8]
# 4                                Angola  366 [237-523]
# ..                                  ...            ...
# 189  Venezuela (Bolivarian Republic of)     30 [23-38]
# 190                            Viet Nam  199 [125-290]
# 191                               Yemen     48 [42-54]
# 192                              Zambia  391 [253-558]
# 193                            Zimbabwe  242 [179-314]
#
# [194 rows x 2 columns]

# %% [markdown]
# ## under 5 mortality rate - DONE

# %%
under5_2015 = pd.read_csv(new_data_path/'under5_bs_2015.csv')
under5_2015
# Out:
#                  Location  Period  \
# 0             Afghanistan    2015
# 1                 Albania    2015
# 2                 Algeria    2015
# 3                 Andorra    2015
# 4                  Angola    2015
# ..                    ...     ...
# 167           Switzerland    2015
# 168  Syrian Arab Republic    2015
# 169            Tajikistan    2015
# 170              Thailand    2015
# 171           Timor-Leste    2015
#
#                                              Indicator        Dim1  \
# 0    Under-five mortality rate (probability of dyin...  Both sexes
# 1    Under-five mortality rate (probability of dyin...  Both sexes
# 2    Under-five mortality rate (probability of dyin...  Both sexes
# 3    Under-five mortality rate (probability of dyin...  Both sexes
# 4    Under-five mortality rate (probability of dyin...  Both sexes
# ..                                                 ...         ...
# 167  Under-five mortality rate (probability of dyin...  Both sexes
# ...

# %%
under5_2015.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Under5Mortality']

# %%
under5_2015
# Out:
#                  Location  Period  \
# 0             Afghanistan    2015
# 1                 Albania    2015
# 2                 Algeria    2015
# 3                 Andorra    2015
# 4                  Angola    2015
# ..                    ...     ...
# 167           Switzerland    2015
# 168  Syrian Arab Republic    2015
# 169            Tajikistan    2015
# 170              Thailand    2015
# 171           Timor-Leste    2015
#
#                                              Indicator        Dim1  \
# 0    Under-five mortality rate (probability of dyin...  Both sexes
# 1    Under-five mortality rate (probability of dyin...  Both sexes
# 2    Under-five mortality rate (probability of dyin...  Both sexes
# 3    Under-five mortality rate (probability of dyin...  Both sexes
# 4    Under-five mortality rate (probability of dyin...  Both sexes
# ..                                                 ...         ...
# 167  Under-five mortality rate (probability of dyin...  Both sexes
# ...

# %%
under5_2015 = under5_2015.drop(['Period', 'Indicator', 'Dim1'], 1)
under5_2015
# Out:
#                  Location      Under5Mortality
# 0             Afghanistan  70.44 [60.72-80.86]
# 1                 Albania     9.57 [9.23-9.94]
# 2                 Algeria  25.18 [24.61-25.75]
# 3                 Andorra    3.53 [1.23-10.59]
# 4                  Angola   88.2 [46.58-149.6]
# ..                    ...                  ...
# 167           Switzerland     4.31 [4.15-4.47]
# 168  Syrian Arab Republic  23.18 [15.76-28.16]
# 169            Tajikistan  37.75 [30.11-47.75]
# 170              Thailand     10.8 [9.5-12.75]
# 171           Timor-Leste  50.76 [34.49-73.94]
#
# [172 rows x 2 columns]

# %% [markdown]
# ## Drinking water services - DONE

# %%
water_2015 = pd.read_csv(new_data_path/'water_data_2015.csv')
water_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                               Andorra    2015
# 4                                Angola    2015
# ..                                  ...     ...
# 188  Venezuela (Bolivarian Republic of)    2015
# 189                            Viet Nam    2015
# 190                               Yemen    2015
# 191                              Zambia    2015
# 192                            Zimbabwe    2015
#
#                                              Indicator  First Tooltip
# 0    Population using at least basic drinking-water...          52.39
# 1    Population using at least basic drinking-water...          89.88
# 2    Population using at least basic drinking-water...          88.69
# 3    Population using at least basic drinking-water...         100.00
# ...

# %%
water_2015.columns = ['Location', 'Period', 'Indicator', 'DrinkingWater']

# %%
water_2015
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2015
# 1                               Albania    2015
# 2                               Algeria    2015
# 3                               Andorra    2015
# 4                                Angola    2015
# ..                                  ...     ...
# 188  Venezuela (Bolivarian Republic of)    2015
# 189                            Viet Nam    2015
# 190                               Yemen    2015
# 191                              Zambia    2015
# 192                            Zimbabwe    2015
#
#                                              Indicator  DrinkingWater
# 0    Population using at least basic drinking-water...          52.39
# 1    Population using at least basic drinking-water...          89.88
# 2    Population using at least basic drinking-water...          88.69
# 3    Population using at least basic drinking-water...         100.00
# ...

# %%
water_2015 = water_2015.drop(['Period', 'Indicator'], 1)
water_2015
# Out:
#                                Location  DrinkingWater
# 0                           Afghanistan          52.39
# 1                               Albania          89.88
# 2                               Algeria          88.69
# 3                               Andorra         100.00
# 4                                Angola          26.71
# ..                                  ...            ...
# 188  Venezuela (Bolivarian Republic of)          95.83
# 189                            Viet Nam          90.73
# 190                               Yemen          54.70
# 191                              Zambia          40.59
# 192                            Zimbabwe          51.03
#
# [193 rows x 2 columns]

# %%
ultimate = pd.merge(ntd_2015, poison_2015, on = "Location", how = "left")

# %%
ultimate1 = pd.merge(ultimate, tob_2015, on = "Location", how = "left")

# %%
ultimate2 = pd.merge(ultimate1, tuber_2015, on = "Location", how = "left")

# %%
ultimate3 = pd.merge(ultimate2, under5_2015, on = "Location", how = "left")

# %%
ultimate4 = pd.merge(ultimate3, water_2015, on = "Location", how = "left")

# %%
ultimate5 = pd.merge(ultimate4, ad_br_2015, on = "Location", how = "left")

# %%
ultimate6 = pd.merge(ultimate5, alcohol_2015, on = "Location", how = "left")

# %%
ultimate7 = pd.merge(ultimate6, sani_2015, on = "Location", how = "left")

# %%
ultimate8 = pd.merge(ultimate7, cancer_2015, on = "Location", how = "left")

# %%
ultimate9 = pd.merge(ultimate8, doc_2015, on = "Location", how = "left")

# %%
ultimate10 = pd.merge(ultimate9, hale_2015, on = "Location", how = "left")

# %%
ultimate11 = pd.merge(ultimate10, hiv_2015, on = "Location", how = "left")

# %%
ultimate12 = pd.merge(ultimate11, inmort_2015, on = "Location", how = "left")

# %%
ultimate13 = pd.merge(ultimate12, leb_2015, on = "Location", how = "left")

# %%
ultimate14 = pd.merge(ultimate13, malaria_2015, on = "Location", how = "left")

# %%
ultimate15 = pd.merge(ultimate14, midwife_2015, on = "Location", how = "left")

# %%
ultimate16 = pd.merge(ultimate15, mmr_2015, on = "Location", how = "left")

# %%
ultimate17 = pd.merge(ultimate16, neo_2015, on = "Location", how = "left")

# %%
ultimate17
# Out:
#                                Location      NTDs  Poisoning  Tobacco  \
# 0                           Afghanistan  13765392       1.22      NaN
# 1                               Albania        16       0.43     29.9
# 2                               Algeria      7561       0.80     19.3
# 3                               Andorra         0        NaN     34.2
# 4                                Angola  18534219       2.95      NaN
# ..                                  ...       ...        ...      ...
# 189  Venezuela (Bolivarian Republic of)    280243       0.30      NaN
# 190                            Viet Nam   4468764       0.93      NaN
# 191                               Yemen   5840695       3.74     22.2
# 192                              Zambia  11830416       3.06     15.4
# 193                            Zimbabwe  10346543       2.37     14.5
#
#       Tuberculosis      Under5Mortality  DrinkingWater  AdBirthRate  Alcohol  \
# ...

# %%
ultimate17.to_csv('training_messy.csv', index = False)

# %% [markdown]
# ## Outer join attempt
# Using left join led to a lot of nulls, so I'm trying outer join.

# %%
outer1 = pd.merge(ntd_2015, poison_2015, on = "Location", how = "outer")

# %%
outer2 = pd.merge(outer1, tob_2015, on = "Location", how = "outer")

# %%
outer3 = pd.merge(outer2, tuber_2015, on = "Location", how = "outer")

# %%
outer4 = pd.merge(outer3, under5_2015, on = "Location", how = "outer")

# %%
outer5 = pd.merge(outer4, water_2015, on = "Location", how = "outer")

# %%
outer6 = pd.merge(outer5, ad_br_2015, on = "Location", how = "outer")

# %%
outer7 = pd.merge(outer6, alcohol_2015, on = "Location", how = "outer")

# %%
outer8 = pd.merge(outer7, sani_2015, on = "Location", how = "outer")

# %%
outer9 = pd.merge(outer8, cancer_2015, on = "Location", how = "outer")

# %%
outer10 = pd.merge(outer9, doc_2015, on = "Location", how = "outer")

# %%
outer11= pd.merge(outer10, hale_2015, on = "Location", how = "outer")

# %%
outer12 = pd.merge(outer11, hiv_2015, on = "Location", how = "outer")

# %%
outer13 = pd.merge(outer12, inmort_2015, on = "Location", how = "outer")

# %%
outer14 = pd.merge(outer13, leb_2015, on = "Location", how = "outer")

# %%
outer15 = pd.merge(outer14, malaria_2015, on = "Location", how = "outer")

# %%
outer16 = pd.merge(outer15, midwife_2015, on = "Location", how = "outer")

# %%
outer17 = pd.merge(outer16, mmr_2015, on = "Location", how = "outer")

# %%
outer18 = pd.merge(outer17, neo_2015, on = "Location", how = "outer")

# %%
outer18
# Out:
#                                Location      NTDs  Poisoning  Tobacco  \
# 0                           Afghanistan  13765392       1.22      NaN
# 1                               Albania        16       0.43     29.9
# 2                               Algeria      7561       0.80     19.3
# 3                               Andorra         0        NaN     34.2
# 4                                Angola  18534219       2.95      NaN
# ..                                  ...       ...        ...      ...
# 189  Venezuela (Bolivarian Republic of)    280243       0.30      NaN
# 190                            Viet Nam   4468764       0.93      NaN
# 191                               Yemen   5840695       3.74     22.2
# 192                              Zambia  11830416       3.06     15.4
# 193                            Zimbabwe  10346543       2.37     14.5
#
#       Tuberculosis      Under5Mortality  DrinkingWater  AdBirthRate  Alcohol  \
# ...

# %%
outer18.isnull().sum()
# Out:
# Location              0
# NTDs                  0
# Poisoning            11
# Tobacco              45
# Tuberculosis          0
# Under5Mortality      22
# DrinkingWater         1
# AdBirthRate          88
# Alcohol               6
# BasicSanitization     1
# CancerEtc            11
# MedDocs              89
# HALE                 11
# HIV                  24
# InfantMortality      22
# LifeExpectancy       11
# Malaria              87
# MidwifeNursing       61
# MaternalMortality    11
# NeonatalMortality     1
# dtype: int64

# %% [markdown]
# ## Outer Join Results
# Same exact null values as with left join.
