# %% [markdown]
# ## Data Notes:
# The test set that is exported from this file is made up of the data in the New Data folder. The data is all from the year 2016 when we could with a few from 2018 and 2019 if the data was only recorded every handful of years.

# %%
import pandas as pd
import pathlib

# %%
new_data_path = pathlib.Path.cwd()/'New Data'

# %% [markdown]
# ## Adolescent Birth Rate

# %%
ad_br_2016 = pd.read_csv(new_data_path/'ad_br_2016.csv')
ad_br_2016
# Out:
#                                               Location  Period  \
# 0                                              Albania    2016
# 1                                              Andorra    2016
# 2                                  Antigua and Barbuda    2016
# 3                                              Armenia    2016
# 4                                            Australia    2016
# ..                                                 ...     ...
# 103  United Kingdom of Great Britain and Northern I...    2016
# 104                        United Republic of Tanzania    2016
# 105                           United States of America    2016
# 106                                            Uruguay    2016
# 107                                         Uzbekistan    2016
#
#                                              Indicator  First Tooltip
# 0    Adolescent birth rate (per 1000 women aged 15-...           17.3
# ...

# %%
ad_br_2016.columns = ['Location', 'Period', 'Indicator', 'AdBirthRate']
ad_br_2016
# Out:
#                                               Location  Period  \
# 0                                              Albania    2016
# 1                                              Andorra    2016
# 2                                  Antigua and Barbuda    2016
# 3                                              Armenia    2016
# 4                                            Australia    2016
# ..                                                 ...     ...
# 103  United Kingdom of Great Britain and Northern I...    2016
# 104                        United Republic of Tanzania    2016
# 105                           United States of America    2016
# 106                                            Uruguay    2016
# 107                                         Uzbekistan    2016
#
#                                              Indicator  AdBirthRate
# 0    Adolescent birth rate (per 1000 women aged 15-...         17.3
# 1    Adolescent birth rate (per 1000 women aged 15-...          2.6
# ...

# %%
ad_br_2016 = ad_br_2016.drop(['Period', 'Indicator'], 1)
ad_br_2016
# Out:
#                                               Location  AdBirthRate
# 0                                              Albania         17.3
# 1                                              Andorra          2.6
# 2                                  Antigua and Barbuda         31.1
# 3                                              Armenia         24.5
# 4                                            Australia         10.3
# ..                                                 ...          ...
# 103  United Kingdom of Great Britain and Northern I...         13.7
# 104                        United Republic of Tanzania        138.9
# 105                           United States of America         20.3
# 106                                            Uruguay         50.3
# 107                                         Uzbekistan         20.9
#
# [108 rows x 2 columns]

# %% [markdown]
# ## Alcohol

# %%
alcohol_2018 = pd.read_csv(new_data_path/'alchohol_bs_2018.csv')
alcohol_2018
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2018
# 1                               Albania    2018
# 2                               Algeria    2018
# 3                               Andorra    2018
# 4                                Angola    2018
# ..                                  ...     ...
# 183  Venezuela (Bolivarian Republic of)    2018
# 184                            Viet Nam    2018
# 185                               Yemen    2018
# 186                              Zambia    2018
# 187                            Zimbabwe    2018
#
#                                              Indicator        Dim1  \
# 0    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# 1    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# 2    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# 3    Total (recorded+unrecorded) alcohol per capita...  Both sexes
# ...

# %%
alcohol_2018.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Alcohol']
alcohol_2018
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2018
# 1                               Albania    2018
# 2                               Algeria    2018
# 3                               Andorra    2018
# 4                                Angola    2018
# ..                                  ...     ...
# 183  Venezuela (Bolivarian Republic of)    2018
# 184                            Viet Nam    2018
# 185                               Yemen    2018
# 186                              Zambia    2018
# 187                            Zimbabwe    2018
#
#                                              Indicator        Dim1  Alcohol
# 0    Total (recorded+unrecorded) alcohol per capita...  Both sexes    0.210
# 1    Total (recorded+unrecorded) alcohol per capita...  Both sexes    7.170
# 2    Total (recorded+unrecorded) alcohol per capita...  Both sexes    0.950
# 3    Total (recorded+unrecorded) alcohol per capita...  Both sexes   11.020
# ...

# %%
alcohol_2018 = alcohol_2018.drop(['Period', 'Indicator', 'Dim1'], 1)
alcohol_2018
# Out:
#                                Location  Alcohol
# 0                           Afghanistan    0.210
# 1                               Albania    7.170
# 2                               Algeria    0.950
# 3                               Andorra   11.020
# 4                                Angola    6.940
# ..                                  ...      ...
# 183  Venezuela (Bolivarian Republic of)    4.140
# 184                            Viet Nam    8.660
# 185                               Yemen    0.051
# 186                              Zambia    6.540
# 187                            Zimbabwe    4.670
#
# [188 rows x 2 columns]

# %% [markdown]
# ## Basic Sanitization

# %%
sani_2016 = pd.read_csv(new_data_path/'basic_sani_tot_2016.csv')
sani_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 186  Venezuela (Bolivarian Republic of)
# 187                            Viet Nam
# 188                               Yemen
# 189                              Zambia
# 190                            Zimbabwe
#
#                                              Indicator  Period   Dim1  \
# 0    Population using at least basic sanitation ser...    2016  Total
# 1    Population using at least basic sanitation ser...    2016  Total
# 2    Population using at least basic sanitation ser...    2016  Total
# 3    Population using at least basic sanitation ser...    2016  Total
# 4    Population using at least basic sanitation ser...    2016  Total
# ...

# %%
sani_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'BasicSanitization']
sani_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 186  Venezuela (Bolivarian Republic of)
# 187                            Viet Nam
# 188                               Yemen
# 189                              Zambia
# 190                            Zimbabwe
#
#                                                 Period  Indicator   Dim1  \
# 0    Population using at least basic sanitation ser...       2016  Total
# 1    Population using at least basic sanitation ser...       2016  Total
# 2    Population using at least basic sanitation ser...       2016  Total
# 3    Population using at least basic sanitation ser...       2016  Total
# 4    Population using at least basic sanitation ser...       2016  Total
# ...

# %%
sani_2016 = sani_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
sani_2016
# Out:
#                                Location  BasicSanitization
# 0                           Afghanistan              42.05
# 1                               Albania              97.70
# 2                               Algeria              87.54
# 3                               Andorra             100.00
# 4                                Angola              48.63
# ..                                  ...                ...
# 186  Venezuela (Bolivarian Republic of)              93.94
# 187                            Viet Nam              81.86
# 188                               Yemen              58.77
# 189                              Zambia              26.09
# 190                            Zimbabwe              36.89
#
# [191 rows x 2 columns]

# %% [markdown]
# ## Cancer

# %%
cancer_2016 = pd.read_csv(new_data_path/'cancer_bs_2016.csv')
cancer_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                                Angola    2016
# 4                   Antigua and Barbuda    2016
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2016
# 179                            Viet Nam    2016
# 180                               Yemen    2016
# 181                              Zambia    2016
# 182                            Zimbabwe    2016
#
#                                              Indicator        Dim1  \
# 0    Probability (%) of dying between age 30 and ex...  Both sexes
# 1    Probability (%) of dying between age 30 and ex...  Both sexes
# 2    Probability (%) of dying between age 30 and ex...  Both sexes
# 3    Probability (%) of dying between age 30 and ex...  Both sexes
# ...

# %%
cancer_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'CancerEtc']
cancer_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                                Angola    2016
# 4                   Antigua and Barbuda    2016
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2016
# 179                            Viet Nam    2016
# 180                               Yemen    2016
# 181                              Zambia    2016
# 182                            Zimbabwe    2016
#
#                                              Indicator        Dim1  CancerEtc
# 0    Probability (%) of dying between age 30 and ex...  Both sexes       29.8
# 1    Probability (%) of dying between age 30 and ex...  Both sexes       17.0
# 2    Probability (%) of dying between age 30 and ex...  Both sexes       14.2
# ...

# %%
cancer_2016 = cancer_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
cancer_2016
# Out:
#                                Location  CancerEtc
# 0                           Afghanistan       29.8
# 1                               Albania       17.0
# 2                               Algeria       14.2
# 3                                Angola       16.5
# 4                   Antigua and Barbuda       22.6
# ..                                  ...        ...
# 178  Venezuela (Bolivarian Republic of)       18.1
# 179                            Viet Nam       17.1
# 180                               Yemen       30.6
# 181                              Zambia       17.9
# 182                            Zimbabwe       19.3
#
# [183 rows x 2 columns]

# %% [markdown]
# ## Medical Doctors

# %%
doc_2016 = pd.read_csv(new_data_path/'doc_2016.csv')
doc_2016
# Out:
#         Location  Period                     Indicator  First Tooltip
# 0    Afghanistan    2016  Medical doctors (per 10,000)           2.78
# 1        Albania    2016  Medical doctors (per 10,000)          12.16
# 2        Algeria    2016  Medical doctors (per 10,000)          18.33
# 3      Argentina    2016  Medical doctors (per 10,000)          40.01
# 4      Australia    2016  Medical doctors (per 10,000)          35.67
# ..           ...     ...                           ...            ...
# 105      Uruguay    2016  Medical doctors (per 10,000)          39.56
# 106      Vanuatu    2016  Medical doctors (per 10,000)           1.65
# 107     Viet Nam    2016  Medical doctors (per 10,000)           8.28
# 108       Zambia    2016  Medical doctors (per 10,000)           1.63
# 109     Zimbabwe    2016  Medical doctors (per 10,000)           1.79
#
# [110 rows x 4 columns]

# %%
doc_2016.columns = ['Location', 'Period', 'Indicator', 'MedDocs']
doc_2016
# Out:
#         Location  Period                     Indicator  MedDocs
# 0    Afghanistan    2016  Medical doctors (per 10,000)     2.78
# 1        Albania    2016  Medical doctors (per 10,000)    12.16
# 2        Algeria    2016  Medical doctors (per 10,000)    18.33
# 3      Argentina    2016  Medical doctors (per 10,000)    40.01
# 4      Australia    2016  Medical doctors (per 10,000)    35.67
# ..           ...     ...                           ...      ...
# 105      Uruguay    2016  Medical doctors (per 10,000)    39.56
# 106      Vanuatu    2016  Medical doctors (per 10,000)     1.65
# 107     Viet Nam    2016  Medical doctors (per 10,000)     8.28
# 108       Zambia    2016  Medical doctors (per 10,000)     1.63
# 109     Zimbabwe    2016  Medical doctors (per 10,000)     1.79
#
# [110 rows x 4 columns]

# %%
doc_2016 = doc_2016.drop(['Period', 'Indicator'], 1)
doc_2016
# Out:
#         Location  MedDocs
# 0    Afghanistan     2.78
# 1        Albania    12.16
# 2        Algeria    18.33
# 3      Argentina    40.01
# 4      Australia    35.67
# ..           ...      ...
# 105      Uruguay    39.56
# 106      Vanuatu     1.65
# 107     Viet Nam     8.28
# 108       Zambia     1.63
# 109     Zimbabwe     1.79
#
# [110 rows x 2 columns]

# %% [markdown]
# ## Healthy Life Expectancy at Birth

# %%
hale_2019 = pd.read_csv(new_data_path/'HALE_bs_2019.csv')
hale_2019
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2019
# 1                               Albania    2019
# 2                               Algeria    2019
# 3                                Angola    2019
# 4                   Antigua and Barbuda    2019
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2019
# 179                            Viet Nam    2019
# 180                               Yemen    2019
# 181                              Zambia    2019
# 182                            Zimbabwe    2019
#
#                                            Indicator        Dim1  \
# 0    Healthy life expectancy (HALE) at birth (years)  Both sexes
# 1    Healthy life expectancy (HALE) at birth (years)  Both sexes
# 2    Healthy life expectancy (HALE) at birth (years)  Both sexes
# 3    Healthy life expectancy (HALE) at birth (years)  Both sexes
# ...

# %%
hale_2019.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'HALE']
hale_2019
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2019
# 1                               Albania    2019
# 2                               Algeria    2019
# 3                                Angola    2019
# 4                   Antigua and Barbuda    2019
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2019
# 179                            Viet Nam    2019
# 180                               Yemen    2019
# 181                              Zambia    2019
# 182                            Zimbabwe    2019
#
#                                            Indicator        Dim1   HALE
# 0    Healthy life expectancy (HALE) at birth (years)  Both sexes  53.95
# 1    Healthy life expectancy (HALE) at birth (years)  Both sexes  69.08
# 2    Healthy life expectancy (HALE) at birth (years)  Both sexes  66.39
# 3    Healthy life expectancy (HALE) at birth (years)  Both sexes  54.84
# ...

# %%
hale_2019 = hale_2019.drop(['Period', 'Indicator', 'Dim1'], 1)
hale_2019
# Out:
#                                Location   HALE
# 0                           Afghanistan  53.95
# 1                               Albania  69.08
# 2                               Algeria  66.39
# 3                                Angola  54.84
# 4                   Antigua and Barbuda  66.97
# ..                                  ...    ...
# 178  Venezuela (Bolivarian Republic of)  64.44
# 179                            Viet Nam  65.30
# 180                               Yemen  57.53
# 181                              Zambia  54.40
# 182                            Zimbabwe  53.07
#
# [183 rows x 2 columns]

# %% [markdown]
# ## New HIV Infections

# %%
hiv_2019 = pd.read_csv(new_data_path/'hiv_bs_2019.csv')
hiv_2019
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2019
# 1                               Albania    2019
# 2                               Algeria    2019
# 3                                Angola    2019
# 4                             Argentina    2019
# ..                                  ...     ...
# 165  Venezuela (Bolivarian Republic of)    2019
# 166                            Viet Nam    2019
# 167                               Yemen    2019
# 168                              Zambia    2019
# 169                            Zimbabwe    2019
#
#                                              Indicator        Dim1  \
# 0    New HIV infections (per 1000 uninfected popula...  Both sexes
# 1    New HIV infections (per 1000 uninfected popula...  Both sexes
# 2    New HIV infections (per 1000 uninfected popula...  Both sexes
# 3    New HIV infections (per 1000 uninfected popula...  Both sexes
# ...

# %%
hiv_2019.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'HIV']
hiv_2019
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2019
# 1                               Albania    2019
# 2                               Algeria    2019
# 3                                Angola    2019
# 4                             Argentina    2019
# ..                                  ...     ...
# 165  Venezuela (Bolivarian Republic of)    2019
# 166                            Viet Nam    2019
# 167                               Yemen    2019
# 168                              Zambia    2019
# 169                            Zimbabwe    2019
#
#                                              Indicator        Dim1  \
# 0    New HIV infections (per 1000 uninfected popula...  Both sexes
# 1    New HIV infections (per 1000 uninfected popula...  Both sexes
# 2    New HIV infections (per 1000 uninfected popula...  Both sexes
# 3    New HIV infections (per 1000 uninfected popula...  Both sexes
# ...

# %%
hiv_2019 = hiv_2019.drop(['Period', 'Indicator', 'Dim1'], 1)
hiv_2019
# Out:
#                                Location               HIV
# 0                           Afghanistan  0.04 [0.01-0.15]
# 1                               Albania              0.03
# 2                               Algeria   0.05 [0.01-0.1]
# 3                                Angola  0.84 [0.59-1.12]
# 4                             Argentina   0.13 [0.1-0.19]
# ..                                  ...               ...
# 165  Venezuela (Bolivarian Republic of)  0.19 [0.12-0.26]
# 166                            Viet Nam  0.05 [0.05-0.06]
# 167                               Yemen  0.04 [0.02-0.08]
# 168                              Zambia  3.17 [2.65-3.88]
# 169                            Zimbabwe  2.81 [1.97-3.87]
#
# [170 rows x 2 columns]

# %% [markdown]
# ## Infant Mortality Rate

# %%
inmort_2016 = pd.read_csv(new_data_path/'in_mort_bs_2016.csv')
inmort_2016
# Out:
#                  Location  Period  \
# 0             Afghanistan    2016
# 1                 Albania    2016
# 2                 Algeria    2016
# 3                 Andorra    2016
# 4                  Angola    2016
# ..                    ...     ...
# 167           Switzerland    2016
# 168  Syrian Arab Republic    2016
# 169            Tajikistan    2016
# 170              Thailand    2016
# 171           Timor-Leste    2016
#
#                                              Indicator        Dim1  \
# 0    Infant mortality rate (probability of dying be...  Both sexes
# 1    Infant mortality rate (probability of dying be...  Both sexes
# 2    Infant mortality rate (probability of dying be...  Both sexes
# 3    Infant mortality rate (probability of dying be...  Both sexes
# 4    Infant mortality rate (probability of dying be...  Both sexes
# ..                                                 ...         ...
# 167  Infant mortality rate (probability of dying be...  Both sexes
# ...

# %%
inmort_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'InfantMortality']
inmort_2016
# Out:
#                  Location  Period  \
# 0             Afghanistan    2016
# 1                 Albania    2016
# 2                 Algeria    2016
# 3                 Andorra    2016
# 4                  Angola    2016
# ..                    ...     ...
# 167           Switzerland    2016
# 168  Syrian Arab Republic    2016
# 169            Tajikistan    2016
# 170              Thailand    2016
# 171           Timor-Leste    2016
#
#                                              Indicator        Dim1  \
# 0    Infant mortality rate (probability of dying be...  Both sexes
# 1    Infant mortality rate (probability of dying be...  Both sexes
# 2    Infant mortality rate (probability of dying be...  Both sexes
# 3    Infant mortality rate (probability of dying be...  Both sexes
# 4    Infant mortality rate (probability of dying be...  Both sexes
# ..                                                 ...         ...
# 167  Infant mortality rate (probability of dying be...  Both sexes
# ...

# %%
inmort_2016 = inmort_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
inmort_2016
# Out:
#                  Location      InfantMortality
# 0             Afghanistan  51.32 [44.36-58.38]
# 1                 Albania     8.38 [8.07-8.72]
# 2                 Algeria  21.28 [20.81-21.75]
# 3                 Andorra     3.2 [1.04-10.24]
# 4                  Angola   55.56 [31.74-90.3]
# ..                    ...                  ...
# 167           Switzerland     3.74 [3.58-3.92]
# 168  Syrian Arab Republic  17.97 [11.75-21.82]
# 169            Tajikistan   32.1 [24.71-41.72]
# 170              Thailand    8.85 [7.76-10.65]
# 171           Timor-Leste  41.86 [28.15-60.63]
#
# [172 rows x 2 columns]

# %% [markdown]
# ## Life Expectancy at Birth

# %%
leb_2019 = pd.read_csv(new_data_path/'leb_bs_2019.csv')
leb_2019
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2019
# 1                               Albania    2019
# 2                               Algeria    2019
# 3                                Angola    2019
# 4                   Antigua and Barbuda    2019
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2019
# 179                            Viet Nam    2019
# 180                               Yemen    2019
# 181                              Zambia    2019
# 182                            Zimbabwe    2019
#
#                             Indicator        Dim1  First Tooltip
# 0    Life expectancy at birth (years)  Both sexes          63.21
# 1    Life expectancy at birth (years)  Both sexes          78.00
# 2    Life expectancy at birth (years)  Both sexes          77.13
# 3    Life expectancy at birth (years)  Both sexes          63.06
# ...

# %%
leb_2019.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'LifeExpectancy']
leb_2019
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2019
# 1                               Albania    2019
# 2                               Algeria    2019
# 3                                Angola    2019
# 4                   Antigua and Barbuda    2019
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2019
# 179                            Viet Nam    2019
# 180                               Yemen    2019
# 181                              Zambia    2019
# 182                            Zimbabwe    2019
#
#                             Indicator        Dim1  LifeExpectancy
# 0    Life expectancy at birth (years)  Both sexes           63.21
# 1    Life expectancy at birth (years)  Both sexes           78.00
# 2    Life expectancy at birth (years)  Both sexes           77.13
# 3    Life expectancy at birth (years)  Both sexes           63.06
# ...

# %%
leb_2019 = leb_2019.drop(['Period', 'Indicator', 'Dim1'], 1)
leb_2019
# Out:
#                                Location  LifeExpectancy
# 0                           Afghanistan           63.21
# 1                               Albania           78.00
# 2                               Algeria           77.13
# 3                                Angola           63.06
# 4                   Antigua and Barbuda           76.45
# ..                                  ...             ...
# 178  Venezuela (Bolivarian Republic of)           73.95
# 179                            Viet Nam           73.74
# 180                               Yemen           66.63
# 181                              Zambia           62.45
# 182                            Zimbabwe           60.68
#
# [183 rows x 2 columns]

# %% [markdown]
# ## Malaria

# %%
malaria_2016 = pd.read_csv(new_data_path/'malaria_2016.csv')
malaria_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Algeria
# 2                                Angola
# 3                             Argentina
# 4                               Armenia
# ..                                  ...
# 102  Venezuela (Bolivarian Republic of)
# 103                            Viet Nam
# 104                               Yemen
# 105                              Zambia
# 106                            Zimbabwe
#
#                                             Indicator  Period  First Tooltip
# 0    Malaria incidence (per 1 000 population at risk)    2016         26.110
# 1    Malaria incidence (per 1 000 population at risk)    2016          0.000
# 2    Malaria incidence (per 1 000 population at risk)    2016        220.000
# 3    Malaria incidence (per 1 000 population at risk)    2016          0.000
# 4    Malaria incidence (per 1 000 population at risk)    2016          0.000
# ...

# %%
malaria_2016.columns = ['Location', 'Period', 'Indicator', 'Malaria']
malaria_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Algeria
# 2                                Angola
# 3                             Argentina
# 4                               Armenia
# ..                                  ...
# 102  Venezuela (Bolivarian Republic of)
# 103                            Viet Nam
# 104                               Yemen
# 105                              Zambia
# 106                            Zimbabwe
#
#                                                Period  Indicator  Malaria
# 0    Malaria incidence (per 1 000 population at risk)       2016   26.110
# 1    Malaria incidence (per 1 000 population at risk)       2016    0.000
# 2    Malaria incidence (per 1 000 population at risk)       2016  220.000
# 3    Malaria incidence (per 1 000 population at risk)       2016    0.000
# 4    Malaria incidence (per 1 000 population at risk)       2016    0.000
# ...

# %%
malaria_2016 = malaria_2016.drop(['Period', 'Indicator'], 1)
malaria_2016
# Out:
#                                Location  Malaria
# 0                           Afghanistan   26.110
# 1                               Algeria    0.000
# 2                                Angola  220.000
# 3                             Argentina    0.000
# 4                               Armenia    0.000
# ..                                  ...      ...
# 102  Venezuela (Bolivarian Republic of)   18.790
# 103                            Viet Nam    0.073
# 104                               Yemen   37.750
# 105                              Zambia  181.400
# 106                            Zimbabwe   65.780
#
# [107 rows x 2 columns]

# %% [markdown]
# ## Nursing and Midwife

# %%
midwife_2016 = pd.read_csv(new_data_path/'midwife_2016.csv')
midwife_2016
# Out:
#                                               Location  Period  \
# 0                                          Afghanistan    2016
# 1                                              Albania    2016
# 2                                              Algeria    2016
# 3                                  Antigua and Barbuda    2016
# 4                                            Argentina    2016
# ..                                                 ...     ...
# 122  United Kingdom of Great Britain and Northern I...    2016
# 123                                           Viet Nam    2016
# 124                                              Yemen    2016
# 125                                             Zambia    2016
# 126                                           Zimbabwe    2016
#
#                                         Indicator  First Tooltip
# 0    Nursing and midwifery personnel (per 10,000)           1.48
# 1    Nursing and midwifery personnel (per 10,000)          36.50
# ...

# %%
midwife_2016.columns = ['Location', 'Period', 'Indicator', 'MidwifeNursing']
midwife_2016
# Out:
#                                               Location  Period  \
# 0                                          Afghanistan    2016
# 1                                              Albania    2016
# 2                                              Algeria    2016
# 3                                  Antigua and Barbuda    2016
# 4                                            Argentina    2016
# ..                                                 ...     ...
# 122  United Kingdom of Great Britain and Northern I...    2016
# 123                                           Viet Nam    2016
# 124                                              Yemen    2016
# 125                                             Zambia    2016
# 126                                           Zimbabwe    2016
#
#                                         Indicator  MidwifeNursing
# 0    Nursing and midwifery personnel (per 10,000)            1.48
# 1    Nursing and midwifery personnel (per 10,000)           36.50
# ...

# %%
midwife_2016 = midwife_2016.drop(['Period', 'Indicator'], 1)
midwife_2016
# Out:
#                                               Location  MidwifeNursing
# 0                                          Afghanistan            1.48
# 1                                              Albania           36.50
# 2                                              Algeria           22.43
# 3                                  Antigua and Barbuda           44.87
# 4                                            Argentina           25.82
# ..                                                 ...             ...
# 122  United Kingdom of Great Britain and Northern I...           82.75
# 123                                           Viet Nam           14.46
# 124                                              Yemen            7.49
# 125                                             Zambia            2.04
# 126                                           Zimbabwe           14.00
#
# [127 rows x 2 columns]

# %% [markdown]
# ## Maternal Mortality Ratio

# %%
mmr_2016 = pd.read_csv(new_data_path/'mmr_2016.csv')
mmr_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                                Angola    2016
# 4                   Antigua and Barbuda    2016
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2016
# 179                            Viet Nam    2016
# 180                               Yemen    2016
# 181                              Zambia    2016
# 182                            Zimbabwe    2016
#
#                                              Indicator   First Tooltip
# 0    Maternal mortality ratio (per 100 000 live bir...  673 [457-1040]
# 1    Maternal mortality ratio (per 100 000 live bir...       16 [8-26]
# 2    Maternal mortality ratio (per 100 000 live bir...    113 [66-203]
# 3    Maternal mortality ratio (per 100 000 live bir...   246 [172-349]
# ...

# %%
mmr_2016.columns = ['Location', 'Period', 'Indicator', 'MaternalMortality']
mmr_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                                Angola    2016
# 4                   Antigua and Barbuda    2016
# ..                                  ...     ...
# 178  Venezuela (Bolivarian Republic of)    2016
# 179                            Viet Nam    2016
# 180                               Yemen    2016
# 181                              Zambia    2016
# 182                            Zimbabwe    2016
#
#                                              Indicator MaternalMortality
# 0    Maternal mortality ratio (per 100 000 live bir...    673 [457-1040]
# 1    Maternal mortality ratio (per 100 000 live bir...         16 [8-26]
# 2    Maternal mortality ratio (per 100 000 live bir...      113 [66-203]
# 3    Maternal mortality ratio (per 100 000 live bir...     246 [172-349]
# ...

# %%
mmr_2016 = mmr_2016.drop(['Period', 'Indicator'], 1)
mmr_2016
# Out:
#                                Location MaternalMortality
# 0                           Afghanistan    673 [457-1040]
# 1                               Albania         16 [8-26]
# 2                               Algeria      113 [66-203]
# 3                                Angola     246 [172-349]
# 4                   Antigua and Barbuda        43 [25-70]
# ..                                  ...               ...
# 178  Venezuela (Bolivarian Republic of)      121 [96-162]
# 179                            Viet Nam        44 [32-61]
# 180                               Yemen     165 [104-249]
# 181                              Zambia     222 [168-295]
# 182                            Zimbabwe     468 [372-580]
#
# [183 rows x 2 columns]

# %% [markdown]
# ## Neonatal Mortality Rate

# %%
neo_2016 = pd.read_csv(new_data_path/'neo_mort_bs_2016.csv')
neo_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                               Andorra    2016
# 4                                Angola    2016
# ..                                  ...     ...
# 188  Venezuela (Bolivarian Republic of)    2016
# 189                            Viet Nam    2016
# 190                               Yemen    2016
# 191                              Zambia    2016
# 192                            Zimbabwe    2016
#
#                                           Indicator        Dim1  \
# 0    Neonatal mortality rate (per 1000 live births)  Both sexes
# 1    Neonatal mortality rate (per 1000 live births)  Both sexes
# 2    Neonatal mortality rate (per 1000 live births)  Both sexes
# 3    Neonatal mortality rate (per 1000 live births)  Both sexes
# ...

# %%
neo_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'NeonatalMortality']
neo_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                               Andorra    2016
# 4                                Angola    2016
# ..                                  ...     ...
# 188  Venezuela (Bolivarian Republic of)    2016
# 189                            Viet Nam    2016
# 190                               Yemen    2016
# 191                              Zambia    2016
# 192                            Zimbabwe    2016
#
#                                           Indicator        Dim1  \
# 0    Neonatal mortality rate (per 1000 live births)  Both sexes
# 1    Neonatal mortality rate (per 1000 live births)  Both sexes
# 2    Neonatal mortality rate (per 1000 live births)  Both sexes
# 3    Neonatal mortality rate (per 1000 live births)  Both sexes
# ...

# %%
neo_2016 = neo_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
neo_2016
# Out:
#                                Location    NeonatalMortality
# 0                           Afghanistan  39.05 [32.59-46.17]
# 1                               Albania     6.33 [5.82-6.82]
# 2                               Algeria  15.07 [14.46-15.67]
# 3                               Andorra     1.63 [0.49-5.42]
# 4                                Angola  29.78 [14.55-53.42]
# ..                                  ...                  ...
# 188  Venezuela (Bolivarian Republic of)  14.62 [13.24-16.09]
# 189                            Viet Nam   11.19 [8.84-13.91]
# 190                               Yemen  26.62 [18.58-37.89]
# 191                              Zambia   24.25 [20.64-28.7]
# 192                            Zimbabwe  27.33 [22.65-32.75]
#
# [193 rows x 2 columns]

# %% [markdown]
# ## NTDs

# %%
ntd_2016 = pd.read_csv(new_data_path/'ntd_2016.csv')
ntd_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                              Indicator  Period  First Tooltip
# 0    Reported number of people requiring interventi...    2016       13275429
# 1    Reported number of people requiring interventi...    2016             21
# 2    Reported number of people requiring interventi...    2016          10752
# 3    Reported number of people requiring interventi...    2016              0
# 4    Reported number of people requiring interventi...    2016       14419092
# ...

# %%
ntd_2016.columns = ['Location', 'Period', 'Indicator', 'NTDs']
ntd_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                                 Period  Indicator      NTDs
# 0    Reported number of people requiring interventi...       2016  13275429
# 1    Reported number of people requiring interventi...       2016        21
# 2    Reported number of people requiring interventi...       2016     10752
# 3    Reported number of people requiring interventi...       2016         0
# 4    Reported number of people requiring interventi...       2016  14419092
# ...

# %%
ntd_2016 = ntd_2016.drop(['Period', 'Indicator'], 1)
ntd_2016
# Out:
#                                Location      NTDs
# 0                           Afghanistan  13275429
# 1                               Albania        21
# 2                               Algeria     10752
# 3                               Andorra         0
# 4                                Angola  14419092
# ..                                  ...       ...
# 189  Venezuela (Bolivarian Republic of)    282294
# 190                            Viet Nam   6953978
# 191                               Yemen   5985649
# 192                              Zambia  11573334
# 193                            Zimbabwe   9958235
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Mortality Rate by Poisoning

# %%
poison_2016 = pd.read_csv(new_data_path/'poison_bs_2016.csv')
poison_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                                Angola
# 4                   Antigua and Barbuda
# ..                                  ...
# 178  Venezuela (Bolivarian Republic of)
# 179                            Viet Nam
# 180                               Yemen
# 181                              Zambia
# 182                            Zimbabwe
#
#                                              Indicator  Period        Dim1  \
# 0    Mortality rate attributed to unintentional poi...    2016  Both sexes
# 1    Mortality rate attributed to unintentional poi...    2016  Both sexes
# 2    Mortality rate attributed to unintentional poi...    2016  Both sexes
# 3    Mortality rate attributed to unintentional poi...    2016  Both sexes
# 4    Mortality rate attributed to unintentional poi...    2016  Both sexes
# ...

# %%
poison_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Poisoning']
poison_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                                Angola
# 4                   Antigua and Barbuda
# ..                                  ...
# 178  Venezuela (Bolivarian Republic of)
# 179                            Viet Nam
# 180                               Yemen
# 181                              Zambia
# 182                            Zimbabwe
#
#                                                 Period  Indicator        Dim1  \
# 0    Mortality rate attributed to unintentional poi...       2016  Both sexes
# 1    Mortality rate attributed to unintentional poi...       2016  Both sexes
# 2    Mortality rate attributed to unintentional poi...       2016  Both sexes
# 3    Mortality rate attributed to unintentional poi...       2016  Both sexes
# 4    Mortality rate attributed to unintentional poi...       2016  Both sexes
# ...

# %%
poison_2016 = poison_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
poison_2016
# Out:
#                                Location  Poisoning
# 0                           Afghanistan       1.19
# 1                               Albania       0.44
# 2                               Algeria       0.77
# 3                                Angola       2.70
# 4                   Antigua and Barbuda       0.39
# ..                                  ...        ...
# 178  Venezuela (Bolivarian Republic of)       0.29
# 179                            Viet Nam       0.92
# 180                               Yemen       3.77
# 181                              Zambia       2.94
# 182                            Zimbabwe       2.23
#
# [183 rows x 2 columns]

# %% [markdown]
# ## Tobacco Age 15

# %%
tob_2016 = pd.read_csv(new_data_path/'tob_2016.csv')
tob_2016
# Out:
#        Location                                          Indicator  Period  \
# 0       Albania  Age-standardized prevalence of current tobacco...    2016
# 1       Algeria  Age-standardized prevalence of current tobacco...    2016
# 2       Andorra  Age-standardized prevalence of current tobacco...    2016
# 3     Argentina  Age-standardized prevalence of current tobacco...    2016
# 4       Armenia  Age-standardized prevalence of current tobacco...    2016
# ..          ...                                                ...     ...
# 144  Uzbekistan  Age-standardized prevalence of current tobacco...    2016
# 145     Vanuatu  Age-standardized prevalence of current tobacco...    2016
# 146       Yemen  Age-standardized prevalence of current tobacco...    2016
# 147      Zambia  Age-standardized prevalence of current tobacco...    2016
# 148    Zimbabwe  Age-standardized prevalence of current tobacco...    2016
#
#            Dim1  First Tooltip
# 0    Both sexes           29.7
# ...

# %%
tob_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Tobacco']
tob_2016
# Out:
#        Location                                             Period  Indicator  \
# 0       Albania  Age-standardized prevalence of current tobacco...       2016
# 1       Algeria  Age-standardized prevalence of current tobacco...       2016
# 2       Andorra  Age-standardized prevalence of current tobacco...       2016
# 3     Argentina  Age-standardized prevalence of current tobacco...       2016
# 4       Armenia  Age-standardized prevalence of current tobacco...       2016
# ..          ...                                                ...        ...
# 144  Uzbekistan  Age-standardized prevalence of current tobacco...       2016
# 145     Vanuatu  Age-standardized prevalence of current tobacco...       2016
# 146       Yemen  Age-standardized prevalence of current tobacco...       2016
# 147      Zambia  Age-standardized prevalence of current tobacco...       2016
# 148    Zimbabwe  Age-standardized prevalence of current tobacco...       2016
#
#            Dim1  Tobacco
# ...

# %%
tob_2016 = tob_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
tob_2016
# Out:
#        Location  Tobacco
# 0       Albania     29.7
# 1       Algeria     19.1
# 2       Andorra     33.9
# 3     Argentina     23.6
# 4       Armenia     27.5
# ..          ...      ...
# 144  Uzbekistan     12.6
# 145     Vanuatu     24.8
# 146       Yemen     21.7
# 147      Zambia     15.2
# 148    Zimbabwe     14.3
#
# [149 rows x 2 columns]

# %% [markdown]
# ## Tuberculosis

# %%
tuber_2016 = pd.read_csv(new_data_path/'tuber_2016.csv')
tuber_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                              Indicator  Period  First Tooltip
# 0    Incidence of tuberculosis (per 100 000 populat...    2016  189 [122-270]
# 1    Incidence of tuberculosis (per 100 000 populat...    2016     17 [14-19]
# 2    Incidence of tuberculosis (per 100 000 populat...    2016     70 [54-89]
# 3    Incidence of tuberculosis (per 100 000 populat...    2016    6 [5.1-6.9]
# 4    Incidence of tuberculosis (per 100 000 populat...    2016  362 [235-518]
# ...

# %%
tuber_2016.columns = ['Location', 'Period', 'Indicator', 'Tuberculosis']
tuber_2016
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# ..                                  ...
# 189  Venezuela (Bolivarian Republic of)
# 190                            Viet Nam
# 191                               Yemen
# 192                              Zambia
# 193                            Zimbabwe
#
#                                                 Period  Indicator  \
# 0    Incidence of tuberculosis (per 100 000 populat...       2016
# 1    Incidence of tuberculosis (per 100 000 populat...       2016
# 2    Incidence of tuberculosis (per 100 000 populat...       2016
# 3    Incidence of tuberculosis (per 100 000 populat...       2016
# 4    Incidence of tuberculosis (per 100 000 populat...       2016
# ..                                                 ...        ...
# ...

# %%
tuber_2016 = tuber_2016.drop(['Period', 'Indicator'], 1)
tuber_2016
# Out:
#                                Location   Tuberculosis
# 0                           Afghanistan  189 [122-270]
# 1                               Albania     17 [14-19]
# 2                               Algeria     70 [54-89]
# 3                               Andorra    6 [5.1-6.9]
# 4                                Angola  362 [235-518]
# ..                                  ...            ...
# 189  Venezuela (Bolivarian Republic of)     34 [26-43]
# 190                            Viet Nam  193 [122-281]
# 191                               Yemen     48 [42-54]
# 192                              Zambia  376 [244-535]
# 193                            Zimbabwe  233 [173-302]
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Under 5 Mortality Rate

# %%
under5_2016 = pd.read_csv(new_data_path/'under5_bs_2016.csv')
under5_2016
# Out:
#                  Location  Period  \
# 0             Afghanistan    2016
# 1                 Albania    2016
# 2                 Algeria    2016
# 3                 Andorra    2016
# 4                  Angola    2016
# ..                    ...     ...
# 167           Switzerland    2016
# 168  Syrian Arab Republic    2016
# 169            Tajikistan    2016
# 170              Thailand    2016
# 171           Timor-Leste    2016
#
#                                              Indicator        Dim1  \
# 0    Under-five mortality rate (probability of dyin...  Both sexes
# 1    Under-five mortality rate (probability of dyin...  Both sexes
# 2    Under-five mortality rate (probability of dyin...  Both sexes
# 3    Under-five mortality rate (probability of dyin...  Both sexes
# 4    Under-five mortality rate (probability of dyin...  Both sexes
# ..                                                 ...         ...
# 167  Under-five mortality rate (probability of dyin...  Both sexes
# ...

# %%
under5_2016.columns = ['Location', 'Period', 'Indicator', 'Dim1', 'Under5Mortality']
under5_2016
# Out:
#                  Location  Period  \
# 0             Afghanistan    2016
# 1                 Albania    2016
# 2                 Algeria    2016
# 3                 Andorra    2016
# 4                  Angola    2016
# ..                    ...     ...
# 167           Switzerland    2016
# 168  Syrian Arab Republic    2016
# 169            Tajikistan    2016
# 170              Thailand    2016
# 171           Timor-Leste    2016
#
#                                              Indicator        Dim1  \
# 0    Under-five mortality rate (probability of dyin...  Both sexes
# 1    Under-five mortality rate (probability of dyin...  Both sexes
# 2    Under-five mortality rate (probability of dyin...  Both sexes
# 3    Under-five mortality rate (probability of dyin...  Both sexes
# 4    Under-five mortality rate (probability of dyin...  Both sexes
# ..                                                 ...         ...
# 167  Under-five mortality rate (probability of dyin...  Both sexes
# ...

# %%
under5_2016 = under5_2016.drop(['Period', 'Indicator', 'Dim1'], 1)
under5_2016
# Out:
#                  Location      Under5Mortality
# 0             Afghanistan  67.57 [57.07-78.65]
# 1                 Albania      9.42 [9.08-9.8]
# 2                 Algeria  24.79 [24.25-25.34]
# 3                 Andorra     3.37 [1.1-10.78]
# 4                  Angola  84.21 [42.56-146.4]
# ..                    ...                  ...
# 167           Switzerland     4.25 [4.06-4.45]
# 168  Syrian Arab Republic  23.27 [15.09-28.55]
# 169            Tajikistan  36.82 [27.93-48.82]
# 170              Thailand   10.32 [9.06-12.38]
# 171           Timor-Leste  49.01 [32.03-74.01]
#
# [172 rows x 2 columns]

# %% [markdown]
# ## Basic Drinking Water Services

# %%
water_2016 = pd.read_csv(new_data_path/'water_data_2016.csv')
water_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                               Andorra    2016
# 4                                Angola    2016
# ..                                  ...     ...
# 187  Venezuela (Bolivarian Republic of)    2016
# 188                            Viet Nam    2016
# 189                               Yemen    2016
# 190                              Zambia    2016
# 191                            Zimbabwe    2016
#
#                                              Indicator  First Tooltip
# 0    Population using at least basic drinking-water...          54.84
# 1    Population using at least basic drinking-water...          89.88
# 2    Population using at least basic drinking-water...          88.69
# 3    Population using at least basic drinking-water...         100.00
# ...

# %%
water_2016.columns = ['Location', 'Period', 'Indicator', 'DrinkingWater']
water_2016
# Out:
#                                Location  Period  \
# 0                           Afghanistan    2016
# 1                               Albania    2016
# 2                               Algeria    2016
# 3                               Andorra    2016
# 4                                Angola    2016
# ..                                  ...     ...
# 187  Venezuela (Bolivarian Republic of)    2016
# 188                            Viet Nam    2016
# 189                               Yemen    2016
# 190                              Zambia    2016
# 191                            Zimbabwe    2016
#
#                                              Indicator  DrinkingWater
# 0    Population using at least basic drinking-water...          54.84
# 1    Population using at least basic drinking-water...          89.88
# 2    Population using at least basic drinking-water...          88.69
# 3    Population using at least basic drinking-water...         100.00
# ...

# %%
water_2016 = water_2016.drop(['Period', 'Indicator'], 1)
water_2016
# Out:
#                                Location  DrinkingWater
# 0                           Afghanistan          54.84
# 1                               Albania          89.88
# 2                               Algeria          88.69
# 3                               Andorra         100.00
# 4                                Angola          27.08
# ..                                  ...            ...
# 187  Venezuela (Bolivarian Republic of)          95.78
# 188                            Viet Nam          91.68
# 189                               Yemen          54.70
# 190                              Zambia          41.18
# 191                            Zimbabwe          50.42
#
# [192 rows x 2 columns]

# %%
big = pd.merge(ntd_2016, poison_2016, on = "Location", how = "left")

# %%
big1 = pd.merge(big, tob_2016, on = "Location", how = "left")

# %%
big2 = pd.merge(big1, tuber_2016, on = "Location", how = "left")

# %%
big3 = pd.merge(big2, under5_2016, on = "Location", how = "left")

# %%
big4 = pd.merge(big3, water_2016, on = "Location", how = "left")

# %%
big5 = pd.merge(big4, ad_br_2016, on = "Location", how = "left")

# %%
big6 = pd.merge(big5, alcohol_2018, on = "Location", how = "left")

# %%
big7 = pd.merge(big6, sani_2016, on = "Location", how = "left")

# %%
big8 = pd.merge(big7, cancer_2016, on = "Location", how = "left")

# %%
big9 = pd.merge(big8, doc_2016, on = "Location", how = "left")

# %%
big10 = pd.merge(big9, hale_2019, on = "Location", how = "left")

# %%
big11 = pd.merge(big10, hiv_2019, on = "Location", how = "left")

# %%
big12 = pd.merge(big11, inmort_2016, on = "Location", how = "left")

# %%
big13 = pd.merge(big12, leb_2019, on = "Location", how = "left")

# %%
big14 = pd.merge(big13, malaria_2016, on = "Location", how = "left")

# %%
big15 = pd.merge(big14, midwife_2016, on = "Location", how = "left")

# %%
big16 = pd.merge(big15, mmr_2016, on = "Location", how = "left")

# %%
big17 = pd.merge(big16, neo_2016, on = "Location", how = "left")

# %%
big17
# Out:
#                                Location      NTDs  Poisoning  Tobacco  \
# 0                           Afghanistan  13275429       1.19      NaN
# 1                               Albania        21       0.44     29.7
# 2                               Algeria     10752       0.77     19.1
# 3                               Andorra         0        NaN     33.9
# 4                                Angola  14419092       2.70      NaN
# ..                                  ...       ...        ...      ...
# 189  Venezuela (Bolivarian Republic of)    282294       0.29      NaN
# 190                            Viet Nam   6953978       0.92      NaN
# 191                               Yemen   5985649       3.77     21.7
# 192                              Zambia  11573334       2.94     15.2
# 193                            Zimbabwe   9958235       2.23     14.3
#
#       Tuberculosis      Under5Mortality  DrinkingWater  AdBirthRate  Alcohol  \
# ...

# %%
big17.isnull().sum()
# Out:
# Location              0
# NTDs                  0
# Poisoning            11
# Tobacco              45
# Tuberculosis          0
# Under5Mortality      22
# DrinkingWater         2
# AdBirthRate          86
# Alcohol               6
# BasicSanitization     3
# CancerEtc            11
# MedDocs              84
# HALE                 11
# HIV                  24
# InfantMortality      22
# LifeExpectancy       11
# Malaria              87
# MidwifeNursing       67
# MaternalMortality    11
# NeonatalMortality     1
# dtype: int64

# %%
big17.to_csv('test_big_messy.csv', index = False)

# %%
test_big = pd.read_csv('test_big_messy.csv')
#test_big

# %%
test_small = test_big.drop(['Tobacco', 'MidwifeNursing', 'HIV', 'Malaria', 'AdBirthRate', 'MedDocs'], 1)
test_small
# Out:
#                                Location      NTDs  Poisoning   Tuberculosis  \
# 0                           Afghanistan  13275429       1.19  189 [122-270]
# 1                               Albania        21       0.44     17 [14-19]
# 2                               Algeria     10752       0.77     70 [54-89]
# 3                               Andorra         0        NaN    6 [5.1-6.9]
# 4                                Angola  14419092       2.70  362 [235-518]
# ..                                  ...       ...        ...            ...
# 189  Venezuela (Bolivarian Republic of)    282294       0.29     34 [26-43]
# 190                            Viet Nam   6953978       0.92  193 [122-281]
# 191                               Yemen   5985649       3.77     48 [42-54]
# 192                              Zambia  11573334       2.94  376 [244-535]
# 193                            Zimbabwe   9958235       2.23  233 [173-302]
#
# ...

# %%
test_small.to_csv('test_small_messy.csv', index = False)

# %% [markdown]
# ## Add tobacco back to small test set

# %%
test_small_cleaner = pd.read_csv('test_small_cleaner.csv')
test_small_cleaner

# %%
tobacco_col = test_big['Tobacco']
tobacco_col
# Out:
# 0       NaN
# 1      29.7
# 2      19.1
# 3      33.9
# 4       NaN
#        ...
# 189     NaN
# 190     NaN
# 191    21.7
# 192    15.2
# 193    14.3
# Name: Tobacco, Length: 194, dtype: float64

# %%
test_small_cleaner['Tobacco'] = tobacco_col

# %%
test_small_cleaner
# Out:
#                                Location      NTDs  Poisoning  Tuberculosis  \
# 0                           Afghanistan  13275429       1.19         189.0
# 1                               Albania        21       0.44          17.0
# 2                               Algeria     10752       0.77          70.0
# 3                               Andorra         0        NaN           6.0
# 4                                Angola  14419092       2.70         362.0
# ..                                  ...       ...        ...           ...
# 189  Venezuela (Bolivarian Republic of)    282294       0.29          34.0
# 190                            Viet Nam   6953978       0.92         193.0
# 191                               Yemen   5985649       3.77          48.0
# 192                              Zambia  11573334       2.94         376.0
# 193                            Zimbabwe   9958235       2.23         233.0
#
# ...

# %%
test_small_cleaner.to_csv('test_cleaner_with_tobacco.csv', index = False)
